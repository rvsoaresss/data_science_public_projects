# %% [markdown]
# Projeto Modulo II
#
# Squad Amarelo - Integrantes:
#
# Daniel Mille
#
# Fernanda Narita
#
# Jessica Andreotti

# %%
from IPython.display import Image
Image(filename='image.png')

# %%
class Produtos:
    def __init__ (self, esquerda, direita, atributo):
        self.esquerda = esquerda
        self.direita = direita
        self.atributo = atributo
   
    def verificar_potencial(self):
        if self.direita == None and self.esquerda == None:
            print("Esse produto vai ser um",self.atributo)
        else:
            print(self.atributo)
            resposta = input('\tDigite "s" para sim e "n" para não')
            if resposta == 's':
                self.esquerda.verificar_potencial()
            elif resposta == 'n':
                self.direita.verificar_potencial()
            else:
                print('\tDigite a opção correta!')
                self.verificar_potencial()
               
vende_muito1 = Produtos(None, None, 'sucesso de vendas')
vende_muito2 = Produtos(None, None, 'sucesso de vendas')
vende_muito3 = Produtos(None, None, 'sucesso de vendas')
vende_muito4 = Produtos(None, None, 'sucesso de vendas')
vende_muito5 = Produtos(None, None, 'sucesso de vendas')
vende_muito6 = Produtos(None, None, 'sucesso de vendas')
nao_vende1 = Produtos(None, None, 'fracasso de vendas')
nao_vende2 = Produtos(None, None, 'fracasso de vendas')
nao_vende3 = Produtos(None, None, 'fracasso de vendas')
preco_medio = Produtos(vende_muito6, nao_vende1, 'A expectativa de preço do produto é médio?')
verao1 = Produtos(vende_muito1, vende_muito2, 'O produto será feito para o verão?')
inverno1 = Produtos(vende_muito3, vende_muito4, 'O produto será feito para o inverno?')
inverno2 = Produtos(vende_muito5, preco_medio, 'O produto será feito para o inverno?')
verao2 = Produtos(nao_vende2, nao_vende3, 'O produto será feito para o verão?')
adulto1 = Produtos(verao1, inverno1, 'O produto é para o público adulto?')
adulto2 = Produtos(inverno2, verao2, 'O produto é para o publico adulto?')
preco_baixo = Produtos(adulto1, adulto2, 'A expectativa de preço do produto é baixo?')

# %%
preco_baixo.verificar_potencial()
# Out:
# A expectativa de preço do produto é baixo?
# 	Digite "s" para sim e "n" para nãos
# O produto é para o público adulto?
# 	Digite "s" para sim e "n" para nãon
# O produto será feito para o inverno?
# 	Digite "s" para sim e "n" para nãos
# Esse produto vai ser um sucesso de vendas
