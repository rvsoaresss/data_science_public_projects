# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import xlrd as xl
from openpyxl import Workbook

# %%
rawdata = pd.read_excel("TCE LA Raw Data - 2019-10.xlsx")

# %%
rawdata
# Out:
#      Raw Data'[Month] Region Raw Data'[Region Detail]     Sub Region  \
# 0              Oct-19    AMS                       LA            MCA
# 1              Oct-19    AMS                       LA         Brazil
# 2              Oct-19    AMS                       LA         Brazil
# 3              Oct-19    AMS                       LA         Brazil
# 4              Oct-19    AMS                       LA         Brazil
# ...               ...    ...                      ...            ...
# 7185           Oct-19    AMS                      NaN  United States
# 7186           Oct-19    AMS                      NaN  United States
# 7187           Oct-19    AMS                      NaN  United States
# 7188           Oct-19    AMS                      NaN  United States
# 7189           Oct-19    AMS                      NaN  United States
#
#                             Area      Country  Business Unit  \
# 0                           BOPE         PERU  Not Specified
# ...

# %%
rawdata2 = rawdata[["'Raw Data'[Month]","'Raw Data'[Region Detail]"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-2d58158d71e7> in <module>
# ----> 1 rawdata2 = rawdata[["'Raw Data'[Month]","'Raw Data'[Region Detail]"]]
#
# c:\users\soaresdo\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2999             if is_iterator(key):
#    3000                 key = list(key)
# -> 3001             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    3002
#    3003         # take() does not accept boolean indexers
#
# c:\users\soaresdo\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
# ...

# %%
rawdata2
