# %%
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_excel("iris.xlsx")

# %%
df
# Out:
#        species  sepal_length sepal_width  sepal_length petal_length  \
# 0       setosa                     17.85                       7.14
# 1       setosa                     14.70                       6.86
# 2       setosa                     15.04                       6.11
# 3       setosa                     14.26                       6.90
# 4       setosa                     18.00                       7.00
# ..         ...                       ...                        ...
# 145  virginica                     20.10                      34.84
# 146  virginica                     15.75                      31.50
# 147  virginica                     19.50                      33.80
# 148  virginica                     21.08                      33.48
# 149  virginica                     17.70                      30.09
#
#      sepal_length petal_width  sepal_width petal_length  \
# 0                        1.02                      4.90
# 1                        0.98                      4.20
# 2                        0.94                      4.16
# 3                        0.92                      4.65
# 4                        1.00                      5.04
# ..                        ...                       ...
# 145                     15.41                     15.60
# 146                     11.97                     12.50
# 147                     13.00                     15.60
# 148                     14.26                     18.36
# 149                     10.62                     15.30
#
#      sepal_width petal_width  petal_length petal_width
# 0                       0.70                      0.28
# 1                       0.60                      0.28
# 2                       0.64                      0.26
# 3                       0.62                      0.30
# 4                       0.72                      0.28
# ..                       ...                       ...
# 145                     6.90                     11.96
# 146                     4.75                      9.50
# 147                     6.00                     10.40
# 148                     7.82                     12.42
# 149                     5.40                      9.18
#
# [150 rows x 7 columns]

# %%
sb.pairplot(df, hue="species")
plt.show()
