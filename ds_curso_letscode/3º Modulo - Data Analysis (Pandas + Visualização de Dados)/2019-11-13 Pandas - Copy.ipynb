# %%
import pandas as pd

# %%
df = pd.read_csv("iris.csv")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.groupby("species").mean()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.428         1.462        0.246
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
df.groupby("species").max()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa               5.8          4.4           1.9          0.6
# versicolor           7.0          3.4           5.1          1.8
# virginica            7.9          3.8           6.9          2.5

# %%
df.groupby("species").min()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa               4.3          2.3           1.0          0.1
# versicolor           4.9          2.0           3.0          1.0
# virginica            4.9          2.2           4.5          1.4

# %%
df["species"].describe().unstack()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-dc4953a25740> in <module>
# ----> 1 df["species"].describe().unstack()
#
# c:\users\soaresdo\appdata\local\programs\python\python37\lib\site-packages\pandas\core\series.py in unstack(self, level, fill_value)
#    3746         from pandas.core.reshape.reshape import unstack
#    3747
# -> 3748         return unstack(self, level, fill_value)
#    3749
#    3750     # ----------------------------------------------------------------------
#
# c:\users\soaresdo\appdata\local\programs\python\python37\lib\site-packages\pandas\core\reshape\reshape.py in unstack(obj, level, fill_value)
#     421             level=level,
#     422             fill_value=fill_value,
# --> 423             constructor=obj._constructor_expanddim,
#     424         )
#     425         return unstacker.get_result()
#
# ...

# %%
df[['species','petal_width']].groupby('species').describe()
# Out:
#            petal_width
#                  count   mean       std  min  25%  50%  75%  max
# species
# setosa            50.0  0.246  0.105386  0.1  0.2  0.2  0.3  0.6
# versicolor        50.0  1.326  0.197753  1.0  1.2  1.3  1.5  1.8
# virginica         50.0  2.026  0.274650  1.4  1.8  2.0  2.3  2.5

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')
